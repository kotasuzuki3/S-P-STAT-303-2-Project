# %%
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels.formula.api as sm
import matplotlib.pyplot as plt
import datetime

# %%
pd.set_option('display.max_columns', None)

# %%
esg = pd.read_csv('ESG_scoredata/ESG_scoredata.csv')

# %%
ratios = pd.read_csv('ESG_scoredata/financial_ratios.csv')

# %%
securitydaily = pd.read_csv('ESG_scoredata/security_daily.csv')
# Out:
# /var/folders/mc/zs1s69ln6dlfsp0q79s_czc40000gn/T/ipykernel_51042/2359471464.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   securitydaily = pd.read_csv('ESG_scoredata/security_daily.csv')

# %% [markdown]
# **Market Capitalization Calculation (annual average for each company)**

# %%
securitydaily.head()
# Out:
#    gvkey iid    datadate   tic      cusip                   conm  ajexdi  \
# 0   1003  01  04/03/2014  ANTQ  000354100  A.A. IMPORTING CO INC     1.0
# 1   1003  01  04/04/2014  ANTQ  000354100  A.A. IMPORTING CO INC     1.0
# 2   1003  01  04/07/2014  ANTQ  000354100  A.A. IMPORTING CO INC     1.0
# 3   1003  01  04/08/2014  ANTQ  000354100  A.A. IMPORTING CO INC     1.0
# 4   1003  01  04/09/2014  ANTQ  000354100  A.A. IMPORTING CO INC     1.0
#
#        cshoc  prccd  trfd
# 0  2683000.0   0.02   NaN
# 1  2683000.0   0.02   NaN
# 2  2683000.0   0.02   NaN
# 3  2683000.0   0.02   NaN
# 4  2683000.0   0.02   NaN

# %%
securitydaily.isna().sum()
# Out:
# gvkey              0
# iid                0
# datadate           0
# tic             4933
# cusip              0
# conm               0
# ajexdi         20099
# cshoc        1031557
# prccd          21382
# trfd        19640760
# dtype: int64

# %%
securitydaily.dropna(subset=['ajexdi','cshoc','prccd','tic'],inplace =True)

# %%
securitydaily['mktcap']= securitydaily['prccd']*securitydaily['cshoc']/securitydaily['ajexdi']

# %%
securitydaily['datadate'] = pd.to_datetime(securitydaily['datadate'])
securitydaily['year'] = securitydaily['datadate'].dt.year

# %%
securitydaily['mktcap_annual'] = securitydaily.groupby(['gvkey','tic','year'])['mktcap'].transform('mean')

# %%
securitydaily.tail()
# Out:
#            gvkey iid   datadate    tic      cusip                      conm  \
# 46931547  353945  90 2022-12-23  ACLLY  00449R109  ACCELLERON INDUSTRIES AG
# 46931548  353945  90 2022-12-27  ACLLY  00449R109  ACCELLERON INDUSTRIES AG
# 46931549  353945  90 2022-12-28  ACLLY  00449R109  ACCELLERON INDUSTRIES AG
# 46931550  353945  90 2022-12-29  ACLLY  00449R109  ACCELLERON INDUSTRIES AG
# 46931551  353945  90 2022-12-30  ACLLY  00449R109  ACCELLERON INDUSTRIES AG
#
#           ajexdi       cshoc   prccd  trfd        mktcap  year  mktcap_annual
# 46931547     1.0  94500000.0  20.483   NaN  1.935644e+09  2022   1.747278e+09
# 46931548     1.0  94500000.0  20.641   NaN  1.950574e+09  2022   1.747278e+09
# 46931549     1.0  94500000.0  20.401   NaN  1.927894e+09  2022   1.747278e+09
# 46931550     1.0  94500000.0  20.720   NaN  1.958040e+09  2022   1.747278e+09
# 46931551     1.0  94500000.0  20.693   NaN  1.955489e+09  2022   1.747278e+09

# %%
mktcap_annualdata = securitydaily.drop(columns=['iid', 'datadate','ajexdi','cshoc','prccd','trfd','mktcap','cusip']).groupby(['gvkey','tic','year']).first().reset_index()

# %%
mktcap_annualdata.head()
# Out:
#    gvkey   tic  year                   conm  mktcap_annual
# 0   1003  ANTQ  2014  A.A. IMPORTING CO INC   5.366000e+04
# 1   1003  ANTQ  2015  A.A. IMPORTING CO INC   5.366000e+04
# 2   1003  ANTQ  2016  A.A. IMPORTING CO INC   5.366000e+04
# 3   1004   AIR  2013               AAR CORP   9.202797e+08
# 4   1004   AIR  2014               AAR CORP   1.059264e+09

# %% [markdown]
# **Financial Ratio Data Cleaning**
#
# *(created annual data, 'year' corresponds to the year in 'adate', take the first observation in the same 'adate' group as a representative for each company-year level)*

# %%
ratios.loc[ratios['gvkey']==24447].head()
# Out:
#         gvkey       adate       qdate public_date     bm    gpm    roe  \
# 177155  24447  12/31/2011  09/30/2012  01/31/2013  0.738  0.951  0.120
# 177156  24447  12/31/2012  12/31/2012  02/28/2013  0.795  0.955  0.123
# 177157  24447  12/31/2012  12/31/2012  03/31/2013  0.795  0.955  0.123
# 177158  24447  12/31/2012  12/31/2012  04/30/2013  0.795  0.955  0.123
# 177159  24447  12/31/2012  03/31/2013  05/31/2013  0.704  0.965  0.122
#
#         debt_assets  curr_ratio  at_turn divyield TICKER     cusip
# 177155        0.889         NaN    0.055    2.71%   BOKF  05561Q20
# 177156        0.894         NaN    0.054    2.56%   BOKF  05561Q20
# 177157        0.894         NaN    0.054    2.44%   BOKF  05561Q20
# 177158        0.894         NaN    0.054    2.43%   BOKF  05561Q20
# 177159        0.889         NaN    0.054    2.33%   BOKF  05561Q20

# %%
ratios_cleaned = ratios.drop(columns=['qdate', 'public_date','cusip']).groupby(['adate','gvkey']).first().reset_index()
ratios_cleaned['adate'] = pd.to_datetime(ratios_cleaned['adate'])
ratios_cleaned['year'] = ratios_cleaned['adate'].dt.year
ratios_cleaned = ratios_cleaned.drop(columns=['adate','divyield'])

# %%
ratios_cleaned.loc[ratios_cleaned['gvkey'] == 24447].head()
# Out:
#        gvkey     bm    gpm    roe  debt_assets  curr_ratio  at_turn TICKER  \
# 10042  24447  0.738  0.951  0.120        0.889         NaN    0.055   BOKF
# 12807  24447  0.795  0.955  0.123        0.894         NaN    0.054   BOKF
# 15813  24447  0.661  0.968  0.106        0.887         NaN    0.049   BOKF
# 18835  24447  0.798  0.950  0.092        0.885         NaN    0.048   BOKF
# 21786  24447  0.820  0.932  0.088        0.896         NaN    0.047   BOKF
#
#        year
# 10042  2011
# 12807  2012
# 15813  2013
# 18835  2014
# 21786  2015

# %%
ratios_cleaned.isna().sum()
# Out:
# gvkey             0
# bm             1902
# gpm            2386
# roe            1990
# debt_assets       0
# curr_ratio     7397
# at_turn        2129
# TICKER          443
# year              0
# dtype: int64

# %%
ratios_cleaned.shape
# Out:
# (41765, 9)

# %%
#merging esg dataset and financial ratios dataset
esg_ratio = pd.merge(esg, ratios_cleaned, left_on=['gvkey','assessmentyear','ticker'],right_on=['gvkey','year','TICKER'], how='inner')

# %%
esg_ratio.isna().sum()
# Out:
# scoreid                              0
# dimensionscoreid                     0
# institutionid                        0
# assessmentyear                       0
# scoredate                            0
# csaindustryname                      0
# csaindustrygroupname                 0
# csaindustryclassificationname        0
# csasectorname                        0
# scoretype                            0
# dimensionname                        0
# aspectname                           0
# scorevalue                        6693
# scoreweight                      18531
# industryrank                      6693
# companyid                            0
# gvkey                                0
# ticker                               0
# companyname                          0
# country                              0
# simpleindustry                       0
# bm                               18334
# gpm                               3164
# roe                              15904
# debt_assets                          0
# curr_ratio                       82317
# at_turn                           2626
# TICKER                               0
# year                                 0
# dtype: int64

# %%
#esg_ratio[esg_ratio['scorevalue'].isna()]

# %%
#droping observations without scorevalue data
esg_ratio.dropna(subset=['scorevalue'],inplace =True)

# %%
esg_ratio.shape
# Out:
# (486177, 29)

# %%
esg_ratio.drop(columns=['scoreid','dimensionscoreid','institutionid','assessmentyear','TICKER'],inplace=True)

# %%
esg_ratio.head()
# Out:
#     scoredate csaindustryname csaindustrygroupname  \
# 0  04/01/2020       BNK Banks                Banks
# 1  04/01/2020       BNK Banks                Banks
# 2  04/01/2020       BNK Banks                Banks
# 3  04/01/2020       BNK Banks                Banks
# 4  04/01/2020       BNK Banks                Banks
#
#   csaindustryclassificationname csasectorname             scoretype  \
# 0                      SAM GICS    Financials  S&P Global ESG Score
# 1                      SAM GICS    Financials              Criteria
# 2                      SAM GICS    Financials              Criteria
# 3                      SAM GICS    Financials              Criteria
# 4                      SAM GICS    Financials              Criteria
#
#                    dimensionname            aspectname  scorevalue  \
# 0           S&P Global ESG Score  S&P Global ESG Score        26.0
# 1        Environmental Dimension      Climate Strategy        42.0
# 2  Economic Governance Dimension   Sustainable Finance        12.0
# 3               Social Dimension      Social Reporting         0.0
# 4  Economic Governance Dimension    Privacy Protection        22.0
#
#    scoreweight  industryrank  companyid  gvkey ticker  \
# 0          NaN         241.0     323261  24447   BOKF
# 1          6.0         198.0     323261  24447   BOKF
# 2          9.0         264.0     323261  24447   BOKF
# 3          4.0         302.0     323261  24447   BOKF
# 4          2.0         254.0     323261  24447   BOKF
#
#                  companyname        country simpleindustry     bm    gpm  \
# 0  BOK Financial Corporation  United States          Banks  0.791  0.792
# 1  BOK Financial Corporation  United States          Banks  0.791  0.792
# 2  BOK Financial Corporation  United States          Banks  0.791  0.792
# 3  BOK Financial Corporation  United States          Banks  0.791  0.792
# 4  BOK Financial Corporation  United States          Banks  0.791  0.792
#
#      roe  debt_assets  curr_ratio  at_turn  year
# 0  0.108        0.885         NaN    0.056  2019
# 1  0.108        0.885         NaN    0.056  2019
# 2  0.108        0.885         NaN    0.056  2019
# 3  0.108        0.885         NaN    0.056  2019
# 4  0.108        0.885         NaN    0.056  2019

# %%
#combining the mktcap data to the esg data and financial ratio data
combined_df = pd.merge(esg_ratio, mktcap_annualdata, left_on=['gvkey','year','ticker'],right_on=['gvkey','year','tic'], how='inner')

# %%
combined_df.drop(columns=['tic'],inplace=True)

# %%
combined_df
# Out:
#          scoredate  csaindustryname csaindustrygroupname  \
# 0       04/01/2020        BNK Banks                Banks
# 1       04/01/2020        BNK Banks                Banks
# 2       04/01/2020        BNK Banks                Banks
# 3       04/01/2020        BNK Banks                Banks
# 4       04/01/2020        BNK Banks                Banks
# ...            ...              ...                  ...
# 482263  03/18/2022  TSV IT services  Software & Services
# 482264  03/18/2022  TSV IT services  Software & Services
# 482265  03/18/2022  TSV IT services  Software & Services
# 482266  03/18/2022  TSV IT services  Software & Services
# 482267  03/18/2022  TSV IT services  Software & Services
#
#        csaindustryclassificationname           csasectorname  \
# 0                           SAM GICS              Financials
# ...      ...                   ...            ...
# 482263  2021  KYNDRYL HOLDINGS INC   4.835787e+09
# 482264  2021  KYNDRYL HOLDINGS INC   4.835787e+09
# 482265  2021  KYNDRYL HOLDINGS INC   4.835787e+09
# 482266  2021  KYNDRYL HOLDINGS INC   4.835787e+09
# 482267  2021  KYNDRYL HOLDINGS INC   4.835787e+09
#
# [482268 rows x 26 columns]

# %%
print(combined_df.companyname.unique().size, combined_df.gvkey.unique().size, combined_df.ticker.unique().size)
# Out:
# 2221 2221 2221

# %%
combined_df.simpleindustry.unique()
# Out:
# array(['Banks', 'Capital Markets', 'Thrifts and Mortgage Finance',
#        'IT Services', 'Hotels, Restaurants and Leisure',
#        'Consumer Finance', 'Insurance',
#        'Health Care Providers and Services',
#        'Commercial Services and Supplies',
#        'Trading Companies and Distributors', 'Industrial Conglomerates',
#        'Technology Hardware, Storage and Peripherals', 'Road and Rail',
#        'Electronic Equipment, Instruments and Components', 'Software',
#        'Real Estate Management and Development', 'Automobiles',
#        'Professional Services', 'Machinery', 'Electric Utilities',
#        'Containers and Packaging', 'Internet and Direct Marketing Retail',
#        'Aerospace and Defense', 'Textiles, Apparel and Luxury Goods',
#        'Oil, Gas and Consumable Fuels', 'Food and Staples Retailing',
#        'Electrical Equipment', 'Pharmaceuticals', 'Auto Components',
#        'Food Products', 'Household Products', 'Household Durables',
#        'Diversified Consumer Services', 'Multi-Utilities', 'Chemicals',
#        'Gas Utilities', 'Diversified Financial Services',
#        'Health Care Equipment and Supplies', 'Multiline Retail',
#        'Metals and Mining', 'Specialty Retail', 'Beverages', 'Airlines',
#        'Water Utilities', 'Distributors', 'Energy Equipment and Services',
#        'Equity Real Estate Investment Trusts (REITs)', 'Entertainment',
#        'Construction and Engineering', 'Building Products',
#        'Wireless Telecommunication Services', 'Media',
#        'Diversified Telecommunication Services',
#        'Semiconductors and Semiconductor Equipment',
#        'Communications Equipment', 'Air Freight and Logistics',
#        'Independent Power and Renewable Electricity Producers',
#        'Paper and Forest Products', 'Construction Materials', 'Tobacco',
#        'Biotechnology', 'Personal Products',
#        'Life Sciences Tools and Services',
#        'Interactive Media and Services', 'Leisure Products',
#        'Health Care Technology', 'Marine'], dtype=object)

# %%
combined_df.csaindustrygroupname.unique()
# Out:
# array(['Banks', 'Diversified Financials', 'Software & Services',
#        'Consumer Services', 'Insurance',
#        'Health Care Equipment & Services',
#        'Commercial & Professional Services', 'Capital Goods',
#        'Technology Hardware & Equipment', 'Transportation', 'Real Estate',
#        'Automobiles & Components', 'Utilities', 'Materials', 'Retailing',
#        'Consumer Durables & Apparel', 'Energy',
#        'Food & Staples Retailing',
#        'Pharmaceuticals, Biotechnology & Life Sciences',
#        'Food, Beverage & Tobacco', 'Household & Personal Products',
#        'Media & Entertainment', 'Telecommunication Services',
#        'Semiconductors & Semiconductor Equipment'], dtype=object)

# %%
#subsetting to dimensional datasets
environmental = combined_df.loc[combined_df['dimensionname'] == 'Environmental Dimension' ]
social = combined_df.loc[combined_df['dimensionname'] == 'Social Dimension' ]
governance = combined_df.loc[combined_df['dimensionname'] == 'Economic Governance Dimension']

# %%
environmental.to_csv('environmental_data.csv')
social.to_csv('social_data.csv')
governance.to_csv('governance_data.csv')
